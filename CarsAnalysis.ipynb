# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv('cars.csv')
cars = cars.drop(columns='Modification')
cars
# Out:
#           Brand           Model  Year Country Condition  Engine_Size  \
# 0        Nissan            720S  2006    Asia      used          3.7
# 1       McLaren     911 Turbo S  2009  Europe       new          5.3
# 2     Chevrolet  M4 Competition  2009     USA       new          5.5
# 3       Bugatti          Chiron  1982    Asia      used          5.4
# 4        Nissan          Chiron  2022  Europe       new          2.4
# ...         ...             ...   ...     ...       ...          ...
# 4995     Nissan            GT-R  2011     USA      used          3.9
# 4996    McLaren  M4 Competition  2021     USA       new          6.9
# 4997    Bugatti     911 Turbo S  1983  Europe       new          6.3
# 4998    Porsche  M4 Competition  2023    Asia       new          7.3
# 4999    McLaren          Chiron  2018  Europe       new          7.7
#
#       Horsepower  Torque  Weight  Top_Speed  ...   Price Mileage Popularity  \
# ...

# %%
# Group by 'Brand' and 'Year' and calculate the mean of 'Top_Speed' for each group
avg_speed_by_year = cars.groupby(['Brand', 'Year'])['Top_Speed'].mean().reset_index()

# Now, plot the average top speed over time for each brand
plt.figure(figsize=(12, 8))

# Loop through each brand to plot their respective trend
for brand in avg_speed_by_year['Brand'].unique():
    brand_data = avg_speed_by_year[avg_speed_by_year['Brand'] == brand]
    plt.plot(brand_data['Year'], brand_data['Top_Speed'], label=brand)

# Label the axes and title
plt.xlabel('Year')
plt.ylabel('Average Top Speed (km/h or mph)')
plt.title('Average Top Speed of Car Brands Over Time')
plt.legend(title='Brand', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
